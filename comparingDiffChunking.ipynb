# %% [markdown]
# <a href="https://colab.research.google.com/github/aekanun2020/2025-AdvancedRAG/blob/main/comparingDiffChunking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# โค้ดตรวจจับรอยต่อระหว่าง Chunks (แก้ไขแล้ว)

# ติดตั้ง library ที่จำเป็น
# !pip install langchain langchain-text-splitters

import re
import time
from langchain.text_splitter import (
    RecursiveCharacterTextSplitter,
    CharacterTextSplitter,
    TokenTextSplitter,
    MarkdownHeaderTextSplitter
)

import re
import time
from langchain.text_splitter import (
    RecursiveCharacterTextSplitter,
    CharacterTextSplitter,
    TokenTextSplitter,
    MarkdownHeaderTextSplitter
)

# สร้างไฟล์ตัวอย่าง
def create_sample_file():
    with open("sample_text.md", "w", encoding="utf-8") as f:
        f.write("""# รายงานการประชุมสามัญผู้ถือหุ้น ประจำปี 2567
ผ่านสื่ออิเล็กทรอนิกส์ (e-meeting)
ของ บริษัท เนชั่น กรุ๊ป (ไทยแลนด์) จำกัด (มหาชน)

## วัน เวลา และสถานที่ประชุม

การประชุมสามัญผู้ถือหุ้น ประจำปี 2567 ของบริษัท เนชั่น กรุ๊ป (ไทยแลนด์) จำกัด (มหาชน) ("บริษัทฯ")
ประชุมเมื่อวันศุกร์ที่ 19 เมษายน 2567 เวลา 14.00 น. ผ่านสื่ออิเล็กทรอนิกส์ (e-meeting) ณ ห้องประชุมสำนักงาน
ของบริษัท ชั้น 10 ถนนเทพรัตน แขวงบางนาใต้ เขตบางนา กรุงเทพมหานคร 10260

## กรรมการบริษัทที่เข้าประชุม และอยู่ในห้องประชุม มีจำนวน 2 ท่าน

1. นายมารุต ธรรคไกรวงศ์         ประธานกรรมการบริษัท
2. นายชนะชัย ลีนะบรรจง         กรรมการอิสระ กรรมการตรวจสอบ
และประธานกรรมการสรรหาและพิจารณาค่าตอบแทน

## กรรมการบริษัทที่เข้าประชุม ผ่านสื่ออิเล็กทรอนิกส์ มีจำนวน 4 ท่าน

1. นายศิริวุฒิ ทองคำ             กรรมการอิสระ และประธานกรรมการตรวจสอบ
2. นายชัยสิทธิ์ ภูวภิรมย์ขวัญ     กรรมการอิสระ กรรมการตรวจสอบ
ประธานกรรมการกำกับกิจการและความยั่งยืน
3. นายเจษฎา บูรณพันธุ์ศรี       กรรมการบริษัท และกรรมการกำกับกิจการและความยั่งยืน
4. นายกำพล แจ้งศิริ แลม         กรรมการบริษัท และกรรมการสรรหาและพิจารณาค่าตอบแทน""")

# อ่านไฟล์
def read_text_file():
    with open("sample_text.md", "r", encoding="utf-8") as f:
        text = f.read()
    return text

# ฟังก์ชันค้นหาข้อความที่ซ้ำกันระหว่างรอยต่อ (แก้ไขใหม่)
def find_overlapping_text(end_text, start_text, min_length=5):
    """
    ค้นหาข้อความที่ซ้ำซ้อนกันระหว่างส่วนท้ายของ chunk หนึ่งและส่วนต้นของ chunk ถัดไป

    Args:
        end_text: ส่วนท้ายของ chunk แรก
        start_text: ส่วนต้นของ chunk ถัดไป
        min_length: ความยาวขั้นต่ำของข้อความที่ซ้ำซ้อนกัน

    Returns:
        dict ที่มีข้อมูลเกี่ยวกับข้อความที่ซ้ำซ้อนกัน (หรือ None ถ้าไม่พบ)

    หมายเหตุ:
        การนับความยาวของข้อความภาษาไทยอาจไม่ตรงกับจำนวนตัวอักษรที่เห็น
        เนื่องจากสระบางตัวและวรรณยุกต์ถูกนับรวมกับตัวอักษร
    """
    # หาความยาวสูงสุดที่เป็นไปได้
    max_possible_length = min(len(end_text), len(start_text))

    # พิจารณาทุกความยาวที่เป็นไปได้ จากมากไปหาน้อย
    for length in range(max_possible_length, min_length - 1, -1):
        # ส่วนท้ายของ end_text ความยาว length
        end_suffix = end_text[-length:]
        # ส่วนต้นของ start_text ความยาว length
        start_prefix = start_text[:length]

        # ตรวจสอบว่าส่วนท้ายของ end_text ตรงกับส่วนต้นของ start_text หรือไม่
        if end_suffix == start_prefix and length >= min_length:
            return {
                'text': end_suffix,
                'length': length
            }

    # ถ้าไม่พบข้อความที่ซ้ำซ้อนกันที่มีความยาวอย่างน้อย min_length
    return None

# ทดสอบ splitter และแสดงผลรอยต่อระหว่าง chunks
def test_chunk_boundaries(chunk_size=1000, chunk_overlap=200):
    # สร้างไฟล์ตัวอย่าง
    create_sample_file()

    # อ่านข้อความ
    text = read_text_file()
    print(f"=================== ORIGINAL TEXT ===================")
    print(text)
    print(f"=====================================================")
    print(f"Text length: {len(text)} characters\n")

    # กำหนด splitters ที่ต้องการทดสอบ
    headers_to_split_on = [
        ("#", "header1"),
        ("##", "header2"),
        ("###", "header3"),
        ("####", "header4"),
    ]

    splitters = [
        (RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap),
         "LangChain RecursiveCharacterTextSplitter"),
        (CharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap),
         "LangChain CharacterTextSplitter"),
        (TokenTextSplitter(chunk_size=chunk_size//4, chunk_overlap=chunk_overlap//4),
         "LangChain TokenTextSplitter"),
        (MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on),
         "LangChain MarkdownHeaderTextSplitter"),
    ]

    for splitter, name in splitters:
        print(f"\n====================================================================")
        print(f"=== Testing {name} ===")
        print(f"====================================================================")

        # อธิบายลักษณะและผลลัพธ์ที่คาดหวังของแต่ละวิธี
        if "RecursiveCharacterTextSplitter" in name:
            print(f"Parameters: chunk_size={chunk_size}, chunk_overlap={chunk_overlap}")
            print("Description: Splits text recursively by different separators (paragraphs, newlines, sentences, etc.)")
            print("Expected results: Should maintain the structure of paragraphs and sentences where possible.")
            print("                 Tends to split at natural boundaries like paragraph breaks or sentence ends.")
            print("                 We expect to see overlaps of approximately the chunk_overlap size.")

        elif "CharacterTextSplitter" in name:
            print(f"Parameters: chunk_size={chunk_size}, chunk_overlap={chunk_overlap}")
            print("Description: Splits text by character count without considering content structure.")
            print("Expected results: Will create uniform chunks of approximately chunk_size length.")
            print("                 May cut in the middle of sentences or even words.")
            print("                 Overlaps will be exactly the chunk_overlap size where possible.")

        elif "TokenTextSplitter" in name:
            print(f"Parameters: chunk_size={chunk_size//4}, chunk_overlap={chunk_overlap//4}")
            print("Description: Splits text based on token counts (similar to how LLMs process text).")
            print("Expected results: Will create chunks based on token count rather than character count.")
            print("                 Chunk size in characters may vary based on token encoding.")
            print("                 Good for maintaining token-level context for LLMs.")

        elif "MarkdownHeaderTextSplitter" in name:
            print(f"Parameters: headers_to_split_on={headers_to_split_on}")
            print("Description: Splits text based on Markdown headers (# or ##).")
            print("Expected results: Each chunk will start with a header and contain all content until the next header.")
            print("                 Chunks may vary greatly in size depending on document structure.")
            print("                 No overlaps between chunks, but maintains document hierarchy.")

        # แยกข้อความ
        if name == "LangChain MarkdownHeaderTextSplitter":
            docs = splitter.split_text(text)
            chunks = [doc.page_content for doc in docs]
        else:
            chunks = splitter.split_text(text)

        print(f"\nNumber of chunks: {len(chunks)}")

        # แสดงข้อมูลแต่ละ chunk
        for i, chunk in enumerate(chunks):
            print(f"\nChunk {i+1}/{len(chunks)} (Length: {len(chunk)}):")
            print(f"{chunk}")

        # วิเคราะห์รอยต่อระหว่าง chunks
        if len(chunks) > 1:
            print("\n--- Boundary Analysis ---")

            overlaps = []

            for i in range(len(chunks) - 1):
                chunk1 = chunks[i]
                chunk2 = chunks[i+1]

                # ใช้ส่วนท้ายและส่วนต้นที่ยาวพอสมควร
                end_section = chunk1[-min(300, len(chunk1)):]  # เพิ่มจำนวนตัวอักษรที่ตรวจสอบ
                start_section = chunk2[:min(300, len(chunk2))]  # เพิ่มจำนวนตัวอักษรที่ตรวจสอบ

                print(f"\nBoundary between chunks {i+1} and {i+2}:")
                print(f"End of chunk {i+1}: \"...{end_section[-100:]}\"")  # แสดงเฉพาะ 100 ตัวสุดท้าย
                print(f"Start of chunk {i+2}: \"{start_section[:100]}...\"")  # แสดงเฉพาะ 100 ตัวแรก

                # ค้นหาข้อความที่ซ้ำซ้อนกัน (ใช้ฟังก์ชันใหม่)
                overlap = find_overlapping_text(end_section, start_section)

                if overlap:
                    print("\nOverlap found:")
                    print(f"Text: \"{overlap['text']}\" (Length: {overlap['length']})")
                    overlaps.append(overlap['length'])
                else:
                    print("\nNo overlap found")
                    overlaps.append(0)

            # วิเคราะห์เพิ่มเติม
            print("\n--- Summary Analysis ---")

            avg_overlap = sum(overlaps) / len(overlaps) if overlaps else 0

            print(f"Average overlap length: {avg_overlap:.2f} characters")
            print(f"Min chunk size: {min(len(chunk) for chunk in chunks)} characters")
            print(f"Max chunk size: {max(len(chunk) for chunk in chunks)} characters")
            print(f"Avg chunk size: {sum(len(chunk) for chunk in chunks) / len(chunks):.2f} characters")

            if "RecursiveCharacterTextSplitter" in name:
                cuts_with_no_overlap = sum(1 for o in overlaps if o == 0)
                print(f"Cuts with no overlap: {cuts_with_no_overlap}/{len(overlaps)} ({cuts_with_no_overlap/len(overlaps)*100:.1f}%)")
                if avg_overlap < chunk_overlap * 0.5 and chunk_overlap > 0:
                    print("Note: Average overlap is significantly less than requested chunk_overlap")
                elif avg_overlap > 0:
                    print("Note: Overlap behavior generally matches expectations")

            elif "CharacterTextSplitter" in name:
                uniformity = max(len(chunk) for chunk in chunks) - min(len(chunk) for chunk in chunks)
                print(f"Chunk size uniformity (max-min): {uniformity} characters")
                if uniformity > chunk_size * 0.2:
                    print("Note: Chunks are less uniform than expected for CharacterTextSplitter")
                else:
                    print("Note: Chunk size uniformity matches expectations")

            elif "MarkdownHeaderTextSplitter" in name:
                # Check if chunks start with headers
                header_starts = sum(1 for chunk in chunks if chunk.lstrip().startswith('#'))
                print(f"Chunks starting with headers: {header_starts}/{len(chunks)} ({header_starts/len(chunks)*100:.1f}%)")
                if header_starts < len(chunks):
                    print("Note: Not all chunks start with headers as expected")
                else:
                    print("Note: Header-based splitting matches expectations")

# รันการทดสอบ
test_chunk_boundaries(chunk_size=500, chunk_overlap=100)
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.11/dist-packages (0.3.25)
# Requirement already satisfied: langchain-text-splitters in /usr/local/lib/python3.11/dist-packages (0.3.8)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.58 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.59)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.42)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.11.4)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (4.13.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2025.4.26)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.58->langchain) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# =================== ORIGINAL TEXT ===================
# # รายงานการประชุมสามัญผู้ถือหุ้น ประจำปี 2567
# ผ่านสื่ออิเล็กทรอนิกส์ (e-meeting)
# ของ บริษัท เนชั่น กรุ๊ป (ไทยแลนด์) จำกัด (มหาชน)
#
# ## วัน เวลา และสถานที่ประชุม
#
# การประชุมสามัญผู้ถือหุ้น ประจำปี 2567 ของบริษัท เนชั่น กรุ๊ป (ไทยแลนด์) จำกัด (มหาชน) ("บริษัทฯ")
# ประชุมเมื่อวันศุกร์ที่ 19 เมษายน 2567 เวลา 14.00 น. ผ่านสื่ออิเล็กทรอนิกส์ (e-meeting) ณ ห้องประชุมสำนักงาน
# ของบริษัท ชั้น 10 ถนนเทพรัตน แขวงบางนาใต้ เขตบางนา กรุงเทพมหานคร 10260
#
# ## กรรมการบริษัทที่เข้าประชุม และอยู่ในห้องประชุม มีจำนวน 2 ท่าน
#
# 1. นายมารุต ธรรคไกรวงศ์         ประธานกรรมการบริษัท
# 2. นายชนะชัย ลีนะบรรจง         กรรมการอิสระ กรรมการตรวจสอบ
# และประธานกรรมการสรรหาและพิจารณาค่าตอบแทน
#
# ## กรรมการบริษัทที่เข้าประชุม ผ่านสื่ออิเล็กทรอนิกส์ มีจำนวน 4 ท่าน
#
# 1. นายศิริวุฒิ ทองคำ             กรรมการอิสระ และประธานกรรมการตรวจสอบ
# 2. นายชัยสิทธิ์ ภูวภิรมย์ขวัญ     กรรมการอิสระ กรรมการตรวจสอบ
# ประธานกรรมการกำกับกิจการและความยั่งยืน
# 3. นายเจษฎา บูรณพันธุ์ศรี       กรรมการบริษัท และกรรมการกำกับกิจการและความยั่งยืน
# 4. นายกำพล แจ้งศิริ แลม         กรรมการบริษัท และกรรมการสรรหาและพิจารณาค่าตอบแทน
# =====================================================
# Text length: 1060 characters
#
#
# ====================================================================
# === Testing LangChain RecursiveCharacterTextSplitter ===
# ====================================================================
# Parameters: chunk_size=500, chunk_overlap=100
# Description: Splits text recursively by different separators (paragraphs, newlines, sentences, etc.)
# Expected results: Should maintain the structure of paragraphs and sentences where possible.
#                  Tends to split at natural boundaries like paragraph breaks or sentence ends.
#                  We expect to see overlaps of approximately the chunk_overlap size.
#
# Number of chunks: 3
#
# Chunk 1/3 (Length: 437):
# # รายงานการประชุมสามัญผู้ถือหุ้น ประจำปี 2567
# ผ่านสื่ออิเล็กทรอนิกส์ (e-meeting)
# ของ บริษัท เนชั่น กรุ๊ป (ไทยแลนด์) จำกัด (มหาชน)
#
# ## วัน เวลา และสถานที่ประชุม
#
# การประชุมสามัญผู้ถือหุ้น ประจำปี 2567 ของบริษัท เนชั่น กรุ๊ป (ไทยแลนด์) จำกัด (มหาชน) ("บริษัทฯ")
# ประชุมเมื่อวันศุกร์ที่ 19 เมษายน 2567 เวลา 14.00 น. ผ่านสื่ออิเล็กทรอนิกส์ (e-meeting) ณ ห้องประชุมสำนักงาน
# ของบริษัท ชั้น 10 ถนนเทพรัตน แขวงบางนาใต้ เขตบางนา กรุงเทพมหานคร 10260
#
# Chunk 2/3 (Length: 286):
# ## กรรมการบริษัทที่เข้าประชุม และอยู่ในห้องประชุม มีจำนวน 2 ท่าน
#
# 1. นายมารุต ธรรคไกรวงศ์         ประธานกรรมการบริษัท
# 2. นายชนะชัย ลีนะบรรจง         กรรมการอิสระ กรรมการตรวจสอบ
# และประธานกรรมการสรรหาและพิจารณาค่าตอบแทน
#
# ## กรรมการบริษัทที่เข้าประชุม ผ่านสื่ออิเล็กทรอนิกส์ มีจำนวน 4 ท่าน
#
# Chunk 3/3 (Length: 402):
# ## กรรมการบริษัทที่เข้าประชุม ผ่านสื่ออิเล็กทรอนิกส์ มีจำนวน 4 ท่าน
#
# 1. นายศิริวุฒิ ทองคำ             กรรมการอิสระ และประธานกรรมการตรวจสอบ
# 2. นายชัยสิทธิ์ ภูวภิรมย์ขวัญ     กรรมการอิสระ กรรมการตรวจสอบ
# ประธานกรรมการกำกับกิจการและความยั่งยืน
# 3. นายเจษฎา บูรณพันธุ์ศรี       กรรมการบริษัท และกรรมการกำกับกิจการและความยั่งยืน
# 4. นายกำพล แจ้งศิริ แลม         กรรมการบริษัท และกรรมการสรรหาและพิจารณาค่าตอบแทน
#
# --- Boundary Analysis ---
#
# Boundary between chunks 1 and 2:
# End of chunk 1: "...meeting) ณ ห้องประชุมสำนักงาน
# ของบริษัท ชั้น 10 ถนนเทพรัตน แขวงบางนาใต้ เขตบางนา กรุงเทพมหานคร 10260"
# Start of chunk 2: "## กรรมการบริษัทที่เข้าประชุม และอยู่ในห้องประชุม มีจำนวน 2 ท่าน
#
# 1. นายมารุต ธรรคไกรวงศ์         ปร..."
#
# No overlap found
#
# Boundary between chunks 2 and 3:
# End of chunk 2: "...กรรมการสรรหาและพิจารณาค่าตอบแทน
#
# ## กรรมการบริษัทที่เข้าประชุม ผ่านสื่ออิเล็กทรอนิกส์ มีจำนวน 4 ท่าน"
# Start of chunk 3: "## กรรมการบริษัทที่เข้าประชุม ผ่านสื่ออิเล็กทรอนิกส์ มีจำนวน 4 ท่าน
#
# 1. นายศิริวุฒิ ทองคำ           ..."
#
# Overlap found:
# Text: "## กรรมการบริษัทที่เข้าประชุม ผ่านสื่ออิเล็กทรอนิกส์ มีจำนวน 4 ท่าน" (Length: 67)
#
# --- Summary Analysis ---
# Average overlap length: 33.50 characters
# Min chunk size: 286 characters
# Max chunk size: 437 characters
# Avg chunk size: 375.00 characters
# Cuts with no overlap: 1/2 (50.0%)
# Note: Average overlap is significantly less than requested chunk_overlap
#
# ====================================================================
# === Testing LangChain CharacterTextSplitter ===
# ====================================================================
# Parameters: chunk_size=500, chunk_overlap=100
# Description: Splits text by character count without considering content structure.
# Expected results: Will create uniform chunks of approximately chunk_size length.
#                  May cut in the middle of sentences or even words.
#                  Overlaps will be exactly the chunk_overlap size where possible.
#
# Number of chunks: 3
#
# Chunk 1/3 (Length: 437):
# # รายงานการประชุมสามัญผู้ถือหุ้น ประจำปี 2567
# ผ่านสื่ออิเล็กทรอนิกส์ (e-meeting)
# ของ บริษัท เนชั่น กรุ๊ป (ไทยแลนด์) จำกัด (มหาชน)
#
# ## วัน เวลา และสถานที่ประชุม
#
# การประชุมสามัญผู้ถือหุ้น ประจำปี 2567 ของบริษัท เนชั่น กรุ๊ป (ไทยแลนด์) จำกัด (มหาชน) ("บริษัทฯ")
# ประชุมเมื่อวันศุกร์ที่ 19 เมษายน 2567 เวลา 14.00 น. ผ่านสื่ออิเล็กทรอนิกส์ (e-meeting) ณ ห้องประชุมสำนักงาน
# ของบริษัท ชั้น 10 ถนนเทพรัตน แขวงบางนาใต้ เขตบางนา กรุงเทพมหานคร 10260
#
# Chunk 2/3 (Length: 286):
# ## กรรมการบริษัทที่เข้าประชุม และอยู่ในห้องประชุม มีจำนวน 2 ท่าน
#
# 1. นายมารุต ธรรคไกรวงศ์         ประธานกรรมการบริษัท
# 2. นายชนะชัย ลีนะบรรจง         กรรมการอิสระ กรรมการตรวจสอบ
# และประธานกรรมการสรรหาและพิจารณาค่าตอบแทน
#
# ## กรรมการบริษัทที่เข้าประชุม ผ่านสื่ออิเล็กทรอนิกส์ มีจำนวน 4 ท่าน
#
# Chunk 3/3 (Length: 402):
# ## กรรมการบริษัทที่เข้าประชุม ผ่านสื่ออิเล็กทรอนิกส์ มีจำนวน 4 ท่าน
#
# 1. นายศิริวุฒิ ทองคำ             กรรมการอิสระ และประธานกรรมการตรวจสอบ
# 2. นายชัยสิทธิ์ ภูวภิรมย์ขวัญ     กรรมการอิสระ กรรมการตรวจสอบ
# ประธานกรรมการกำกับกิจการและความยั่งยืน
# 3. นายเจษฎา บูรณพันธุ์ศรี       กรรมการบริษัท และกรรมการกำกับกิจการและความยั่งยืน
# 4. นายกำพล แจ้งศิริ แลม         กรรมการบริษัท และกรรมการสรรหาและพิจารณาค่าตอบแทน
#
# --- Boundary Analysis ---
#
# Boundary between chunks 1 and 2:
# End of chunk 1: "...meeting) ณ ห้องประชุมสำนักงาน
# ของบริษัท ชั้น 10 ถนนเทพรัตน แขวงบางนาใต้ เขตบางนา กรุงเทพมหานคร 10260"
# Start of chunk 2: "## กรรมการบริษัทที่เข้าประชุม และอยู่ในห้องประชุม มีจำนวน 2 ท่าน
#
# 1. นายมารุต ธรรคไกรวงศ์         ปร..."
#
# No overlap found
#
# Boundary between chunks 2 and 3:
# End of chunk 2: "...กรรมการสรรหาและพิจารณาค่าตอบแทน
#
# ## กรรมการบริษัทที่เข้าประชุม ผ่านสื่ออิเล็กทรอนิกส์ มีจำนวน 4 ท่าน"
# Start of chunk 3: "## กรรมการบริษัทที่เข้าประชุม ผ่านสื่ออิเล็กทรอนิกส์ มีจำนวน 4 ท่าน
#
# 1. นายศิริวุฒิ ทองคำ           ..."
#
# Overlap found:
# Text: "## กรรมการบริษัทที่เข้าประชุม ผ่านสื่ออิเล็กทรอนิกส์ มีจำนวน 4 ท่าน" (Length: 67)
#
# --- Summary Analysis ---
# Average overlap length: 33.50 characters
# Min chunk size: 286 characters
# Max chunk size: 437 characters
# Avg chunk size: 375.00 characters
# Chunk size uniformity (max-min): 151 characters
# Note: Chunks are less uniform than expected for CharacterTextSplitter
#
# ====================================================================
# === Testing LangChain TokenTextSplitter ===
# ====================================================================
# Parameters: chunk_size=125, chunk_overlap=25
# Description: Splits text based on token counts (similar to how LLMs process text).
# Expected results: Will create chunks based on token count rather than character count.
#                  Chunk size in characters may vary based on token encoding.
#                  Good for maintaining token-level context for LLMs.
#
# Number of chunks: 19
#
# Chunk 1/19 (Length: 70):
# # รายงานการประชุมสามัญผู้ถือหุ้น ประจำปี 2567
# ผ่านสื่ออิเล็กทรอนิกส์ (
#
# Chunk 2/19 (Length: 81):
# เล็กทรอนิกส์ (e-meeting)
# ของ บริษัท เนชั่น กรุ๊ป (ไทยแลนด์) จำกัด (มหาชน)
#
# ## วัน
#
# Chunk 3/19 (Length: 71):
# �ด (มหาชน)
#
# ## วัน เวลา และสถานที่ประชุม
#
# การประชุมสามัญผู้ถือหุ้น ประ�
#
# Chunk 4/19 (Length: 76):
# �้ถือหุ้น ประจำปี 2567 ของบริษัท เนชั่น กรุ๊ป (ไทยแลนด์) จำกัด (มหาชน) ("บริ
#
# Chunk 5/19 (Length: 83):
# กัด (มหาชน) ("บริษัทฯ")
# ประชุมเมื่อวันศุกร์ที่ 19 เมษายน 2567 เวลา 14.00 น. ผ่านสื�
#
# Chunk 6/19 (Length: 80):
# ลา 14.00 น. ผ่านสื่ออิเล็กทรอนิกส์ (e-meeting) ณ ห้องประชุมสำนักงาน
# ของบริษัท ช�
#
# Chunk 7/19 (Length: 74):
# น
# ของบริษัท ชั้น 10 ถนนเทพรัตน แขวงบางนาใต้ เขตบางนา กรุงเทพมหานคร 10260
#
#
#
# Chunk 8/19 (Length: 72):
# �งเทพมหานคร 10260
#
# ## กรรมการบริษัทที่เข้าประชุม และอยู่ในห้องประชุม มีจ
#
# Chunk 9/19 (Length: 73):
# ้องประชุม มีจำนวน 2 ท่าน
#
# 1. นายมารุต ธรรคไกรวงศ์         ประธานกรรมการบ�
#
# Chunk 10/19 (Length: 70):
# ะธานกรรมการบริษัท
# 2. นายชนะชัย ลีนะบรรจง         กรรมการอิสระ กรรมการต
#
# Chunk 11/19 (Length: 67):
# ิสระ กรรมการตรวจสอบ
# และประธานกรรมการสรรหาและพิจารณาค่าตอบแทน
#
# ## ก�
#
# Chunk 12/19 (Length: 67):
# ค่าตอบแทน
#
# ## กรรมการบริษัทที่เข้าประชุม ผ่านสื่ออิเล็กทรอนิกส์ มี�
#
# Chunk 13/19 (Length: 76):
# �กทรอนิกส์ มีจำนวน 4 ท่าน
#
# 1. นายศิริวุฒิ ทองคำ             กรรมการอิสระ แล�
#
# Chunk 14/19 (Length: 68):
# �มการอิสระ และประธานกรรมการตรวจสอบ
# 2. นายชัยสิทธิ์ ภูวภิรมย์ขวัญ
#
# Chunk 15/19 (Length: 67):
# �ภิรมย์ขวัญ     กรรมการอิสระ กรรมการตรวจสอบ
# ประธานกรรมการกำกับกิจก�
#
# Chunk 16/19 (Length: 69):
# การกำกับกิจการและความยั่งยืน
# 3. นายเจษฎา บูรณพันธุ์ศรี       กรรมการ�
#
# Chunk 17/19 (Length: 69):
# �ี       กรรมการบริษัท และกรรมการกำกับกิจการและความยั่งยืน
# 4. นายกำพล
#
# Chunk 18/19 (Length: 71):
# �ยืน
# 4. นายกำพล แจ้งศิริ แลม         กรรมการบริษัท และกรรมการสรรหาและพิ
#
# Chunk 19/19 (Length: 27):
# �ารสรรหาและพิจารณาค่าตอบแทน
#
# --- Boundary Analysis ---
#
# Boundary between chunks 1 and 2:
# End of chunk 1: "...# รายงานการประชุมสามัญผู้ถือหุ้น ประจำปี 2567
# ผ่านสื่ออิเล็กทรอนิกส์ ("
# Start of chunk 2: "เล็กทรอนิกส์ (e-meeting)
# ของ บริษัท เนชั่น กรุ๊ป (ไทยแลนด์) จำกัด (มหาชน)
#
# ## วัน..."
#
# Overlap found:
# Text: "เล็กทรอนิกส์ (" (Length: 14)
#
# Boundary between chunks 2 and 3:
# End of chunk 2: "...เล็กทรอนิกส์ (e-meeting)
# ของ บริษัท เนชั่น กรุ๊ป (ไทยแลนด์) จำกัด (มหาชน)
#
# ## วัน"
# Start of chunk 3: "�ด (มหาชน)
#
# ## วัน เวลา และสถานที่ประชุม
#
# การประชุมสามัญผู้ถือหุ้น ประ�..."
#
# No overlap found
#
# Boundary between chunks 3 and 4:
# End of chunk 3: "...�ด (มหาชน)
#
# ## วัน เวลา และสถานที่ประชุม
#
# การประชุมสามัญผู้ถือหุ้น ประ�"
# Start of chunk 4: "�้ถือหุ้น ประจำปี 2567 ของบริษัท เนชั่น กรุ๊ป (ไทยแลนด์) จำกัด (มหาชน) ("บริ..."
#
# No overlap found
#
# Boundary between chunks 4 and 5:
# End of chunk 4: "...�้ถือหุ้น ประจำปี 2567 ของบริษัท เนชั่น กรุ๊ป (ไทยแลนด์) จำกัด (มหาชน) ("บริ"
# Start of chunk 5: "กัด (มหาชน) ("บริษัทฯ")
# ประชุมเมื่อวันศุกร์ที่ 19 เมษายน 2567 เวลา 14.00 น. ผ่านสื�..."
#
# Overlap found:
# Text: "กัด (มหาชน) ("บริ" (Length: 17)
#
# Boundary between chunks 5 and 6:
# End of chunk 5: "...กัด (มหาชน) ("บริษัทฯ")
# ประชุมเมื่อวันศุกร์ที่ 19 เมษายน 2567 เวลา 14.00 น. ผ่านสื�"
# Start of chunk 6: "ลา 14.00 น. ผ่านสื่ออิเล็กทรอนิกส์ (e-meeting) ณ ห้องประชุมสำนักงาน
# ของบริษัท ช�..."
#
# No overlap found
#
# Boundary between chunks 6 and 7:
# End of chunk 6: "...ลา 14.00 น. ผ่านสื่ออิเล็กทรอนิกส์ (e-meeting) ณ ห้องประชุมสำนักงาน
# ของบริษัท ช�"
# Start of chunk 7: "น
# ของบริษัท ชั้น 10 ถนนเทพรัตน แขวงบางนาใต้ เขตบางนา กรุงเทพมหานคร 10260
#
# ..."
#
# No overlap found
#
# Boundary between chunks 7 and 8:
# End of chunk 7: "...น
# ของบริษัท ชั้น 10 ถนนเทพรัตน แขวงบางนาใต้ เขตบางนา กรุงเทพมหานคร 10260
#
# "
# Start of chunk 8: "�งเทพมหานคร 10260
#
# ## กรรมการบริษัทที่เข้าประชุม และอยู่ในห้องประชุม มีจ..."
#
# No overlap found
#
# Boundary between chunks 8 and 9:
# End of chunk 8: "...�งเทพมหานคร 10260
#
# ## กรรมการบริษัทที่เข้าประชุม และอยู่ในห้องประชุม มีจ"
# Start of chunk 9: "้องประชุม มีจำนวน 2 ท่าน
#
# 1. นายมารุต ธรรคไกรวงศ์         ประธานกรรมการบ�..."
#
# Overlap found:
# Text: "้องประชุม มีจ" (Length: 13)
#
# Boundary between chunks 9 and 10:
# End of chunk 9: "...้องประชุม มีจำนวน 2 ท่าน
#
# 1. นายมารุต ธรรคไกรวงศ์         ประธานกรรมการบ�"
# Start of chunk 10: "ะธานกรรมการบริษัท
# 2. นายชนะชัย ลีนะบรรจง         กรรมการอิสระ กรรมการต..."
#
# No overlap found
#
# Boundary between chunks 10 and 11:
# End of chunk 10: "...ะธานกรรมการบริษัท
# 2. นายชนะชัย ลีนะบรรจง         กรรมการอิสระ กรรมการต"
# Start of chunk 11: "ิสระ กรรมการตรวจสอบ
# และประธานกรรมการสรรหาและพิจารณาค่าตอบแทน
#
# ## ก�..."
#
# Overlap found:
# Text: "ิสระ กรรมการต" (Length: 13)
#
# Boundary between chunks 11 and 12:
# End of chunk 11: "...ิสระ กรรมการตรวจสอบ
# และประธานกรรมการสรรหาและพิจารณาค่าตอบแทน
#
# ## ก�"
# Start of chunk 12: "ค่าตอบแทน
#
# ## กรรมการบริษัทที่เข้าประชุม ผ่านสื่ออิเล็กทรอนิกส์ มี�..."
#
# No overlap found
#
# Boundary between chunks 12 and 13:
# End of chunk 12: "...ค่าตอบแทน
#
# ## กรรมการบริษัทที่เข้าประชุม ผ่านสื่ออิเล็กทรอนิกส์ มี�"
# Start of chunk 13: "�กทรอนิกส์ มีจำนวน 4 ท่าน
#
# 1. นายศิริวุฒิ ทองคำ             กรรมการอิสระ แล�..."
#
# No overlap found
#
# Boundary between chunks 13 and 14:
# End of chunk 13: "...�กทรอนิกส์ มีจำนวน 4 ท่าน
#
# 1. นายศิริวุฒิ ทองคำ             กรรมการอิสระ แล�"
# Start of chunk 14: "�มการอิสระ และประธานกรรมการตรวจสอบ
# 2. นายชัยสิทธิ์ ภูวภิรมย์ขวัญ    ..."
#
# No overlap found
#
# Boundary between chunks 14 and 15:
# End of chunk 14: "...�มการอิสระ และประธานกรรมการตรวจสอบ
# 2. นายชัยสิทธิ์ ภูวภิรมย์ขวัญ    "
# Start of chunk 15: "�ภิรมย์ขวัญ     กรรมการอิสระ กรรมการตรวจสอบ
# ประธานกรรมการกำกับกิจก�..."
#
# No overlap found
#
# Boundary between chunks 15 and 16:
# End of chunk 15: "...�ภิรมย์ขวัญ     กรรมการอิสระ กรรมการตรวจสอบ
# ประธานกรรมการกำกับกิจก�"
# Start of chunk 16: "การกำกับกิจการและความยั่งยืน
# 3. นายเจษฎา บูรณพันธุ์ศรี       กรรมการ�..."
#
# No overlap found
#
# Boundary between chunks 16 and 17:
# End of chunk 16: "...การกำกับกิจการและความยั่งยืน
# 3. นายเจษฎา บูรณพันธุ์ศรี       กรรมการ�"
# Start of chunk 17: "�ี       กรรมการบริษัท และกรรมการกำกับกิจการและความยั่งยืน
# 4. นายกำพล..."
#
# No overlap found
#
# Boundary between chunks 17 and 18:
# End of chunk 17: "...�ี       กรรมการบริษัท และกรรมการกำกับกิจการและความยั่งยืน
# 4. นายกำพล"
# Start of chunk 18: "�ยืน
# 4. นายกำพล แจ้งศิริ แลม         กรรมการบริษัท และกรรมการสรรหาและพิ..."
#
# No overlap found
#
# Boundary between chunks 18 and 19:
# End of chunk 18: "...�ยืน
# 4. นายกำพล แจ้งศิริ แลม         กรรมการบริษัท และกรรมการสรรหาและพิ"
# Start of chunk 19: "�ารสรรหาและพิจารณาค่าตอบแทน..."
#
# No overlap found
#
# --- Summary Analysis ---
# Average overlap length: 3.17 characters
# Min chunk size: 27 characters
# Max chunk size: 83 characters
# Avg chunk size: 70.05 characters
#
# ====================================================================
# === Testing LangChain MarkdownHeaderTextSplitter ===
# ====================================================================
# Parameters: headers_to_split_on=[('#', 'header1'), ('##', 'header2'), ('###', 'header3'), ('####', 'header4')]
# Description: Splits text based on Markdown headers (# or ##).
# Expected results: Each chunk will start with a header and contain all content until the next header.
#                  Chunks may vary greatly in size depending on document structure.
#                  No overlaps between chunks, but maintains document hierarchy.
#
# Number of chunks: 4
#
# Chunk 1/4 (Length: 83):
# ผ่านสื่ออิเล็กทรอนิกส์ (e-meeting)
# ของ บริษัท เนชั่น กรุ๊ป (ไทยแลนด์) จำกัด (มหาชน)
#
# Chunk 2/4 (Length: 276):
# การประชุมสามัญผู้ถือหุ้น ประจำปี 2567 ของบริษัท เนชั่น กรุ๊ป (ไทยแลนด์) จำกัด (มหาชน) ("บริษัทฯ")
# ประชุมเมื่อวันศุกร์ที่ 19 เมษายน 2567 เวลา 14.00 น. ผ่านสื่ออิเล็กทรอนิกส์ (e-meeting) ณ ห้องประชุมสำนักงาน
# ของบริษัท ชั้น 10 ถนนเทพรัตน แขวงบางนาใต้ เขตบางนา กรุงเทพมหานคร 10260
#
# Chunk 3/4 (Length: 151):
# 1. นายมารุต ธรรคไกรวงศ์         ประธานกรรมการบริษัท
# 2. นายชนะชัย ลีนะบรรจง         กรรมการอิสระ กรรมการตรวจสอบ
# และประธานกรรมการสรรหาและพิจารณาค่าตอบแทน
#
# Chunk 4/4 (Length: 333):
# 1. นายศิริวุฒิ ทองคำ             กรรมการอิสระ และประธานกรรมการตรวจสอบ
# 2. นายชัยสิทธิ์ ภูวภิรมย์ขวัญ     กรรมการอิสระ กรรมการตรวจสอบ
# ประธานกรรมการกำกับกิจการและความยั่งยืน
# 3. นายเจษฎา บูรณพันธุ์ศรี       กรรมการบริษัท และกรรมการกำกับกิจการและความยั่งยืน
# 4. นายกำพล แจ้งศิริ แลม         กรรมการบริษัท และกรรมการสรรหาและพิจารณาค่าตอบแทน
#
# --- Boundary Analysis ---
#
# Boundary between chunks 1 and 2:
# End of chunk 1: "...ผ่านสื่ออิเล็กทรอนิกส์ (e-meeting)
# ของ บริษัท เนชั่น กรุ๊ป (ไทยแลนด์) จำกัด (มหาชน)"
# Start of chunk 2: "การประชุมสามัญผู้ถือหุ้น ประจำปี 2567 ของบริษัท เนชั่น กรุ๊ป (ไทยแลนด์) จำกัด (มหาชน) ("บริษัทฯ")
# ปร..."
#
# No overlap found
#
# Boundary between chunks 2 and 3:
# End of chunk 2: "...meeting) ณ ห้องประชุมสำนักงาน
# ของบริษัท ชั้น 10 ถนนเทพรัตน แขวงบางนาใต้ เขตบางนา กรุงเทพมหานคร 10260"
# Start of chunk 3: "1. นายมารุต ธรรคไกรวงศ์         ประธานกรรมการบริษัท
# 2. นายชนะชัย ลีนะบรรจง         กรรมการอิสระ กรรม..."
#
# No overlap found
#
# Boundary between chunks 3 and 4:
# End of chunk 3: "...
# 2. นายชนะชัย ลีนะบรรจง         กรรมการอิสระ กรรมการตรวจสอบ
# และประธานกรรมการสรรหาและพิจารณาค่าตอบแทน"
# Start of chunk 4: "1. นายศิริวุฒิ ทองคำ             กรรมการอิสระ และประธานกรรมการตรวจสอบ
# 2. นายชัยสิทธิ์ ภูวภิรมย์ขวัญ ..."
#
# No overlap found
#
# --- Summary Analysis ---
# Average overlap length: 0.00 characters
# Min chunk size: 83 characters
# Max chunk size: 333 characters
# Avg chunk size: 210.75 characters
# Chunks starting with headers: 0/4 (0.0%)
# Note: Not all chunks start with headers as expected
